# %%
# %matplotlib inline
import numpy as np              #numpy bilioteca de operaciones matemáticas
import matplotlib.pyplot as plt #matplotlib para "plotear" los gráficos
#import control as ct            #control biblioteca para operar Bode
import control

import warnings
warnings.filterwarnings('ignore')

# %%
# La función es una operación entre polinomios (Numerador/Denominador)
# Los coeficientes de mayor grado están a la izquierda y se completan todos. si hay uno nulo se coloca un `cero`.
Gtf = control.tf([4],[1/4,1])
print(Gtf)
# Out:
# <TransferFunction>: sys[0]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
#
#
#     4
# ----------
# 0.25 s + 1

# %% [markdown]
# EJERCICIO 1a
# ### FUNCION DE TRANSFERENCIA
#
# $$H(s)= \frac{1}{(\frac{s}{4})+1}$$

# %%
#mag,phase,omega = control.bode(Gtf,dB=True,Hz=True, grid=False, color="green")
#mag,phase, omega = control.bode(G)
Gtf = control.tf([4], [1,4])
w = np.logspace(-1,5,100) # Genera un vector de 200 puntos entre 10^-1 y 10^6
control.bode_plot(Gtf,dB=True,Hz=True, grid=True, color="red")
#control.bode_plot(Gtf,w,wrap_phase=True,dB=True,Hz=True, grid=False, color="green")

# %% [markdown]
# EJERCICIO 1b
# ### FUNCION DE TRANSFERENCIA
#
# $$H(s)= \frac{1}{2}\frac{1}{(\frac{s}{2})+1}$$

# %%
Gtf = 0.5*control.tf([1,0], [1,2])
w = np.logspace(-1,5,100) # Genera un vector de 200 puntos entre 10^-1 y 10^6
control.bode_plot(Gtf,w,dB=True,Hz=False, grid=True, color="red")
print(Gtf)
# Out:
# <TransferFunction>: sys[5]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
#
#
# 0.5 s
# -----
# s + 2

# %% [markdown]
# EJERCICIO 1c
# ### FUNCION DE TRANSFERENCIA
#
# $$G(s) = 0.7 \frac {s(s+5.5)}{(s+8.7)}$$

# %%
Gtf =0.7*control.tf([1,5.5,0],[1,8.7])
print(Gtf)
w = np.logspace(-1,2,500)
control.bode_plot(Gtf,w,dB=True,Hz=False, wrap_phase=True, grid=True, color="blue")
# Out:
# <TransferFunction>: sys[9]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
#
#
# 0.7 s^2 + 3.85 s
# ----------------
#     s + 8.7

# %% [markdown]
# EJERCICIO 3a
# ### FUNCION DE TRANSFERENCIA
#
# $$G(s) = 10^5 \frac {(\frac{s}{10^5}+1)}{(\frac{s}{10^3}+1)(\frac{s}{10^4}+1)}$$

# %%
Gtf = (100000)*control.tf([1,(100000)],[1,11000,10000000])
print(Gtf)
w = np.logspace(-1,7,500)
control.bode_plot(Gtf,w,dB=True,Hz=False, wrap_phase=True, grid=True, color="orange")
# Out:
# <TransferFunction>: sys[48]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
#
#
#     1e+05 s + 1e+10
# -----------------------
# s^2 + 1.1e+04 s + 1e+07
