# %%
# %matplotlib inline
import numpy as np              #numpy bilioteca de operaciones matemáticas
import matplotlib.pyplot as plt #matplotlib para "plotear" los gráficos
#import control as ct            #control biblioteca para operar Bode
import control

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# $$H(s)= 100 \frac{s+10}{s^2 +1100s + 100000}$$

# %%
# La función es una operación entre polinomios (Numerador/Denominador)
# Los coeficientes de mayor grado están a la izquierda y se completan todos. si hay uno nulo se coloca un `cero`.
Gtf = 100*control.tf([1,10],[1,1100,100000])
print(Gtf)
# Out:
# <TransferFunction>: sys[2]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
#
#
#     100 s + 1000
# --------------------
# s^2 + 1100 s + 1e+05

# %% [markdown]
# $$G(s)= 0.001 \frac{(s+1)(s+10)}{(s+100 )^2(s+ 1000)}$$

# %%
# La función es una operación entre polinomios (Numerador/Denominador)
# Los coeficientes de mayor grado están a la izquierda y se completan todos. si hay uno nulo se coloca un `cero`.
Gtf_1 = 0.001*control.tf([1,11,10],[1,1200,210000,10000000])
print(Gtf_1)
# Out:
# <TransferFunction>: sys[5]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
#
#
#     0.001 s^2 + 0.011 s + 0.01
# ----------------------------------
# s^3 + 1200 s^2 + 2.1e+05 s + 1e+07

# %%
w = np.logspace(-1,6,200) # Genera un vector de 200 puntos entre 10^-1 y 10^6

# %%
#mag,phase,omega = control.bode(Gtf,dB=True,Hz=True, grid=False, color="green")
#mag,phase, omega = control.bode(G)
w = np.logspace(-1, 6, 200)  # Genera un vector de 200 puntos entre 10^-1 y 10^6
Gtf_1 = 1e9 * control.tf([1, 11, 10], [1, 1200, 210000, 10000000])
control.bode_plot(Gtf_1, w, dB=True, Hz=True, grid=False, color="red")  # Se pasa 'w' explícitamente
print(Gtf_1)
#control.bode_plot(Gtf,w,wrap_phase=True,dB=True,Hz=True, grid=False, color="green")
# Out:
# <TransferFunction>: sys[32]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
#
#
#   1e+09 s^2 + 1.1e+10 s + 1e+10
# ----------------------------------
# s^3 + 1200 s^2 + 2.1e+05 s + 1e+07
